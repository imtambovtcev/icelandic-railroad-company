# %%
import json
import warnings
from utils import generate_lattice
import geopandas as gpd
import numpy as np
import pandas as pd
from shapely.geometry import Point, box

# Suppress deprecation warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
with open("../data/standard_variables.json", "r") as f:
    standard_variables = json.load(f)

standard_variables
# Out:
# {'map_limits': {'north': 64.188968,
#   'south': 64.033992,
#   'east': -21.640345,
#   'west': -22.083955},
#  'grid_size': {'unit': 'meters', 'value': 100},
#  'standard_variables': {'cutoff_radius': {'unit': 'meters', 'value': 400}}}

# %%
map_limits = standard_variables["map_limits"]
grid_size = standard_variables["grid_size"]["value"]

lattice_points = generate_lattice(map_limits, grid_size)

print(f"Generated {len(lattice_points)} lattice points")
print(lattice_points[:5])
# Out:
# Generated 195624 lattice points
# [(-22.083955, 64.033992), (-22.083056684715878, 64.033992), (-22.08215836943176, 64.033992), (-22.08126005414764, 64.033992), (-22.08036173886352, 64.033992)]

# %%
def estimate_parking_for_lattice_optimized(gdf, points, radius):
    """
    Efficiently estimate parking capacity for a lattice of points.

    Parameters:
    - gdf (GeoDataFrame): GeoDataFrame containing parking lot data with an 'estimated_capacity' column.
    - points (list of tuples): List of (longitude, latitude) tuples representing locations to search near.
    - radius (float): The search radius in meters.

    Returns:
    - results (list of dict): List containing total capacity and nearby parking lots for each point.
    """
    # Reproject GeoDataFrame to metric CRS only once
    gdf_metric = gdf.to_crs(epsg=3857)
    spatial_index = gdf_metric.sindex  # Build spatial index once

    # Reproject all points to metric CRS at once
    points_metric = gpd.GeoSeries(
        [Point(pt) for pt in points], crs=gdf.crs
    ).to_crs(epsg=3857)

    results = []
    for idx, point in enumerate(points_metric):
        # Create a buffer around the point
        search_area = point.buffer(radius)

        # Use the spatial index to find potential matches
        possible_matches_index = list(
            spatial_index.intersection(search_area.bounds))
        possible_matches = gdf_metric.iloc[possible_matches_index]

        # Filter with exact intersection
        nearby_parking = possible_matches[possible_matches.intersects(
            search_area)]

        # Calculate the total estimated capacity
        total_capacity = nearby_parking['estimated_capacity'].sum()

        results.append({
            "point_index": idx,
            "location": points[idx],
            "total_capacity": total_capacity,
            "nearby_parking": nearby_parking
        })

    return results

# %%
gdf_parkings = gpd.read_file("../data/parking_lots.geojson")

# Check if the CRS is correct (should be WGS84 for compatibility with the function)
if gdf_parkings.crs != "EPSG:4326":
    gdf_parkings = gdf_parkings.to_crs(epsg=4326)

display(gdf_parkings)
# Out:
#      element_type     osmid access  amenity capacity   fee       parking  \
# 0             way   4347334   None  parking     None  None   street_side
# 1             way   4370534    yes  parking     None    no       surface
# 2             way   4383232   None  parking     None  None          None
# 3             way   4403322    yes  parking     None    no       surface
# 4             way   4403323   None  parking     None  None          None
# ...           ...       ...    ...      ...      ...   ...           ...
# 4414     relation  11762330    yes  parking     None    no   street_side
# 4415     relation  12668440    yes  parking     None    no       surface
# 4416     relation  12859326    yes  parking     None    no  multi-storey
# 4417     relation  16810737    yes  parking     None    no       surface
# 4418     relation  17298330   None  parking     None  None       surface
#
#       surface operator covered capacity:disabled  calculated_area  \
# 0        None     None    None              None       597.881119
# 1        None     None    None              None      1990.194635
# 2        None     None    None              None      2264.271066
# 3     asphalt     None    None               yes     13498.502969
# 4        None     None    None              None      4739.967403
# ...       ...      ...     ...               ...              ...
# 4414     None     None    None                 1       610.990884
# 4415  asphalt     None    None              None     27053.659708
# 4416    paved     None    None              None     50861.404633
# 4417  asphalt     None    None              None      2145.629491
# 4418     None     None    None              None     12290.076571
#
#       estimated_capacity                                           geometry
# 0               3.477211  MULTIPOLYGON (((-21.93892 64.15974, -21.93884 ...
# 1              11.574755  MULTIPOLYGON (((-21.92879 64.14502, -21.92844 ...
# 2              13.168754  MULTIPOLYGON (((-21.97168 64.14855, -21.97167 ...
# 3              78.505823  MULTIPOLYGON (((-21.92808 64.12218, -21.92814 ...
# 4              27.567134  MULTIPOLYGON (((-21.92845 64.12237, -21.92956 ...
# ...                  ...                                                ...
# 4414            3.553456  MULTIPOLYGON (((-21.93391 64.14635, -21.93420 ...
# 4415          157.341138  MULTIPOLYGON (((-21.90188 64.13776, -21.90088 ...
# 4416          295.804389  MULTIPOLYGON (((-21.84834 64.14296, -21.84833 ...
# 4417           12.478747  MULTIPOLYGON (((-21.66358 64.16824, -21.66344 ...
# 4418           71.477747  MULTIPOLYGON (((-21.92100 64.13984, -21.92105 ...
#
# [4419 rows x 14 columns]

# %%
results = estimate_parking_for_lattice_optimized(
    gdf_parkings, lattice_points, standard_variables['standard_variables']['cutoff_radius']['value'])

# Display results
for result in results[:5]:
    print(f"Point {result['point_index']} (Location: {result['location']}):")
    print(f"  Total parking capacity: {result['total_capacity']}")
# Out:
# Point 0 (Location: (-22.083955, 64.033992)):
#   Total parking capacity: 0.0
# Point 1 (Location: (-22.083056684715878, 64.033992)):
#   Total parking capacity: 0.0
# Point 2 (Location: (-22.08215836943176, 64.033992)):
#   Total parking capacity: 0.0
# Point 3 (Location: (-22.08126005414764, 64.033992)):
#   Total parking capacity: 0.0
# Point 4 (Location: (-22.08036173886352, 64.033992)):
#   Total parking capacity: 0.0

# %%
# Prepare the results for saving
results_list = []
for result in results:
    results_list.append({
        "point_index": result["point_index"],
        "latitude": result["location"][1],
        "longitude": result["location"][0],
        "total_capacity": result["total_capacity"]
    })

# Convert to DataFrame
results_df = pd.DataFrame(results_list)

# Save as CSV
results_df.to_csv("../data/lattice_parking_capacity.csv", index=False)

print("Results have been saved as 'lattice_parking_capacity.csv'.")
# Out:
# Results have been saved as 'lattice_parking_capacity.csv'.

# %%
gpd_district_geom = gpd.read_file('../data/pop_district_geom_fixed.geojson')
display(gpd_district_geom)
# Out:
#      smsv                                   smsv_label  \
# 0    0101           Reykjavík: Vesturbær norður - 0101
# 1    0102           Reykjavík: Vesturbær norður - 0102
# 2    0103           Reykjavík: Vesturbær norður - 0103
# 3    0104           Reykjavík: Vesturbær norður - 0104
# 4    3101            Suðurnes án Reykjanesbæjar - 3101
# ..    ...                                          ...
# 200  3402                            Vestfirðir - 3402
# 201  0705  Reykjavík: Háaleiti og Bústaðahverfi - 0705
# 202  3303                Vesturland án Akraness - 3303
# 203  0603         Reykjavík: Laugardalur austur - 0603
# 204  3801                 Akureyri: Ofan Brekku - 3801
#
#                                     smsv_label_en Medaltal  \
# 0              Reykjavik: Vesturbaer north - 0101     1379
# 1              Reykjavik: Vesturbaer north - 0102     1243
# 2              Reykjavik: Vesturbaer north - 0103     1267
# 3              Reykjavik: Vesturbaer north - 0104     1071
# 4            Southwest excl. Reykjanesbaer - 3101     2093
# ..                                            ...      ...
# 200                             Westfjords - 3402     1075
# 201  Reykjavik: Haaleiti and Bustadahverfi - 0705     1892
# 202                    West excl. Akraness - 3303     1437
# 203            Reykjavik: Laugardalur east - 0603      924
# 204                         Akureyri: west - 3801     2075
#
#                                               geometry
# 0    MULTIPOLYGON (((-21.95516 64.14637, -21.95490 ...
# 1    MULTIPOLYGON (((-21.94822 64.14279, -21.94802 ...
# 2    MULTIPOLYGON (((-21.94597 64.14783, -21.94475 ...
# 3    MULTIPOLYGON (((-21.94609 64.15015, -21.94430 ...
# 4    MULTIPOLYGON (((-22.42807 63.94181, -22.42805 ...
# ..                                                 ...
# 200  MULTIPOLYGON (((-22.65863 66.09024, -22.65748 ...
# 201  MULTIPOLYGON (((-21.87431 64.11726, -21.87431 ...
# 202  MULTIPOLYGON (((-20.87857 64.70605, -20.87973 ...
# 203  MULTIPOLYGON (((-21.87529 64.14680, -21.87528 ...
# 204  MULTIPOLYGON (((-18.07985 65.66451, -18.07948 ...
#
# [205 rows x 5 columns]

# %%
points_gdf = gpd.GeoDataFrame(
    geometry=[Point(x, y) for x, y in lattice_points],
    crs="EPSG:4326"
)

# Ensure the district GeoDataFrame has the same CRS
if gpd_district_geom.crs != points_gdf.crs:
    gpd_district_geom = gpd_district_geom.to_crs(points_gdf.crs)

# Perform the spatial join to find which district each point belongs to
district_gdf = gpd.sjoin(points_gdf, gpd_district_geom,
                         how="left", predicate="within")

# Retrieve the `smsv` and other relevant information
result = district_gdf[["geometry", "smsv",
                       "smsv_label", "smsv_label_en", "Medaltal"]]

print(result)
# Out:
#                           geometry  smsv                      smsv_label  \
# 0       POINT (-22.08395 64.03399)  1501  Hafnarfjörður: Suðurbær - 1501
# 1       POINT (-22.08306 64.03399)  1501  Hafnarfjörður: Suðurbær - 1501
# 2       POINT (-22.08216 64.03399)  1501  Hafnarfjörður: Suðurbær - 1501
# 3       POINT (-22.08126 64.03399)  1501  Hafnarfjörður: Suðurbær - 1501
# 4       POINT (-22.08036 64.03399)  1501  Hafnarfjörður: Suðurbær - 1501
# ...                            ...   ...                             ...
# 195619  POINT (-21.64468 64.18892)  2401      Mosfellsbær og Kjós - 2401
# 195620  POINT (-21.64378 64.18892)  2401      Mosfellsbær og Kjós - 2401
# 195621  POINT (-21.64288 64.18892)  2401      Mosfellsbær og Kjós - 2401
# 195622  POINT (-21.64198 64.18892)  2401      Mosfellsbær og Kjós - 2401
# 195623  POINT (-21.64109 64.18892)  2401      Mosfellsbær og Kjós - 2401
#
#                            smsv_label_en Medaltal
# 0       Hafnarfjoerdur: Sudurbaer - 1501     1797
# 1       Hafnarfjoerdur: Sudurbaer - 1501     1797
# 2       Hafnarfjoerdur: Sudurbaer - 1501     1797
# 3       Hafnarfjoerdur: Sudurbaer - 1501     1797
# 4       Hafnarfjoerdur: Sudurbaer - 1501     1797
# ...                                  ...      ...
# 195619      Mosfellsbaer and Kjos - 2401     2085
# 195620      Mosfellsbaer and Kjos - 2401     2085
# 195621      Mosfellsbaer and Kjos - 2401     2085
# 195622      Mosfellsbaer and Kjos - 2401     2085
# 195623      Mosfellsbaer and Kjos - 2401     2085
#
# [195624 rows x 5 columns]

# %%
district_gdf.to_file("../data/district_lattice.geojson", driver='GeoJSON')

# %%
buildings_with_population = gpd.read_file(
    "../data/buildings_with_population.geojson")
display(buildings_with_population)
# Out:
#        smsv  calculated_area  Medaltal    total_area    growth  \
# 0      0405      3883.959942    2619.0  3.717841e+05  1.000000
# 1      2105      4752.141405    1154.0  3.757481e+05  1.338843
# 2      2105     56989.880228    1154.0  3.757481e+05  1.338843
# 3      0405      3505.833698    2619.0  3.717841e+05  1.000000
# 4      0401      2448.573105    2258.0  4.778074e+05  1.000000
# ...     ...              ...       ...           ...       ...
# 47165  0501      9431.840269    2628.0  5.635955e+05  1.202532
# 47166  1203      3382.092624    1693.0  2.793860e+05  1.012821
# 47167  1101      9086.683094    1467.0  1.103674e+06  1.000000
# 47168  1101     15493.000624    1467.0  1.103674e+06  1.000000
# 47169  1803      6562.909127    2095.0  1.134007e+06  1.149425
#
#        population_2025  population_2029  population_2030  \
# 0            27.360212        27.360212        27.360212
# 1            14.594807        19.540155        26.161199
# 2           175.027683       234.334584       313.737211
# 3            24.696535        24.696535        24.696535
# 4            11.571352        11.571352        11.571352
# ...                ...              ...              ...
# 47165        43.979903        52.887225        63.598561
# 47166        20.494525        20.757275        21.023394
# 47167        12.077992        12.077992        12.077992
# 47168        20.593251        20.593251        20.593251
# 47169        12.124523        13.936233        16.018658
#
#                                                 geometry
# 0      MULTIPOLYGON (((-21.91400 64.14308, -21.91387 ...
# 1      MULTIPOLYGON (((-21.88009 64.10280, -21.87926 ...
# 2      MULTIPOLYGON (((-21.88060 64.10358, -21.87837 ...
# 3      MULTIPOLYGON (((-21.91381 64.14119, -21.91343 ...
# 4      MULTIPOLYGON (((-21.89905 64.11787, -21.89931 ...
# ...                                                  ...
# 47165  MULTIPOLYGON (((-21.90116 64.14565, -21.90108 ...
# 47166  MULTIPOLYGON (((-21.79414 64.15055, -21.79434 ...
# 47167  MULTIPOLYGON (((-21.82900 64.12973, -21.82904 ...
# 47168  MULTIPOLYGON (((-21.82823 64.12915, -21.82902 ...
# 47169  MULTIPOLYGON (((-21.89734 64.07000, -21.89696 ...
#
# [47170 rows x 9 columns]

# %%
def estimate_population_for_lattice_optimized(gdf, points, radius):
    """
    Efficiently estimate population in proximity to a lattice of points.

    Parameters:
    - gdf (GeoDataFrame): GeoDataFrame containing population data with 'population_2025', 'population_2029', 'population_2030' columns.
    - points (list of tuples): List of (longitude, latitude) tuples representing locations to search near.
    - radius (float): The search radius in meters.

    Returns:
    - results (list of dict): List containing total population and nearby buildings for each point.
    """
    # Reproject GeoDataFrame to metric CRS only once
    gdf_metric = gdf.to_crs(epsg=3857)
    spatial_index = gdf_metric.sindex  # Build spatial index once

    # Reproject all points to metric CRS at once
    points_metric = gpd.GeoSeries(
        [Point(pt) for pt in points], crs=gdf.crs
    ).to_crs(epsg=3857)

    results = []
    for idx, point in enumerate(points_metric):
        # Create a buffer around the point
        search_area = point.buffer(radius)

        # Use the spatial index to find potential matches
        possible_matches_index = list(
            spatial_index.intersection(search_area.bounds))
        possible_matches = gdf_metric.iloc[possible_matches_index]

        # Filter with exact intersection
        nearby_buildings = possible_matches[possible_matches.intersects(
            search_area)]

        # Calculate the total population for each year
        total_population_2025 = nearby_buildings['population_2025'].sum()
        total_population_2029 = nearby_buildings['population_2029'].sum()
        total_population_2030 = nearby_buildings['population_2030'].sum()

        results.append({
            "point_index": idx,
            "location": points[idx],
            "total_population_2025": total_population_2025,
            "total_population_2029": total_population_2029,
            "total_population_2030": total_population_2030,
            "nearby_buildings": nearby_buildings
        })

    return results


# Example usage
results = estimate_population_for_lattice_optimized(
    buildings_with_population, lattice_points, standard_variables['standard_variables']['cutoff_radius']['value'])

# %%
# Display results
for result in results[:5]:
    print(f"Point {result['point_index']} (Location: {result['location']}):")
    print(f"  Total population (2025): {result['total_population_2025']}")
    print(f"  Total population (2029): {result['total_population_2029']}")
    print(f"  Total population (2030): {result['total_population_2030']}")
# Out:
# Point 0 (Location: (-22.083955, 64.033992)):
#   Total population (2025): 0.0
#   Total population (2029): 0.0
#   Total population (2030): 0.0
# Point 1 (Location: (-22.083056684715878, 64.033992)):
#   Total population (2025): 0.0
#   Total population (2029): 0.0
#   Total population (2030): 0.0
# Point 2 (Location: (-22.08215836943176, 64.033992)):
#   Total population (2025): 0.0
#   Total population (2029): 0.0
#   Total population (2030): 0.0
# Point 3 (Location: (-22.08126005414764, 64.033992)):
#   Total population (2025): 0.0
#   Total population (2029): 0.0
#   Total population (2030): 0.0
# Point 4 (Location: (-22.08036173886352, 64.033992)):
#   Total population (2025): 0.0
#   Total population (2029): 0.0
#   Total population (2030): 0.0

# %%
# Prepare the results for saving
population_results_list = []
for result in results:
    population_results_list.append({
        "point_index": result["point_index"],
        "latitude": result["location"][1],
        "longitude": result["location"][0],
        "total_population_2025": result["total_population_2025"],
        "total_population_2029": result["total_population_2029"],
        "total_population_2030": result["total_population_2030"]
    })

# Convert to DataFrame
population_results_df = pd.DataFrame(population_results_list)

# Save as CSV
population_results_df.to_csv(
    "../data/lattice_population_proximity.csv", index=False)

print("Population results have been saved as '../data/lattice_population_proximity.csv'.")
# Out:
# Population results have been saved as '../data/lattice_population_proximity.csv'.

# %%
poi_data = gpd.read_file("../data/poi_data.geojson")
display(poi_data)
# Out:
#                           Name   Latitude  Longitude  Weight  Reviews  \
# 0            Whales of Iceland  64.155407 -21.948319     3.0     2593
# 1                     Lavashow  64.156987 -21.942981     3.0     2309
# 2                  Saga Museum  64.152589 -21.951381     3.0     1709
# 3    Reykjavík Maritime Museum  64.153298 -21.948718     3.0      940
# 4        Árbær Open Air Museum  64.118911 -21.816251     3.0     1099
# ..                         ...        ...        ...     ...      ...
# 274         Reykjavík Terminal  64.134114 -21.920854     1.0      245
# 275    Destination Blue Lagoon  64.133936 -21.920063     1.0       52
# 276             Airport Direct  64.134190 -21.920156     2.0      267
# 277       Viðey Ferry Terminal  64.156234 -21.867257     1.0       24
# 278       SKarfarbakki Harbour  64.156131 -21.864768     2.0      661
#
#            Type    category   score  normalized_score  \
# 0    Exhibition     Tourism  2593.0          0.109710
# 1    Exhibition     Tourism  2309.0          0.097694
# 2        Museum     Tourism  1709.0          0.072308
# 3        Museum     Tourism   940.0          0.039772
# 4        Museum     Tourism  1099.0          0.046499
# ..          ...         ...     ...               ...
# 274        None  Trans. Hub  2450.0          0.103660
# 275        None  Trans. Hub   520.0          0.022001
# 276        None  Trans. Hub  2670.0          0.112968
# 277        None  Trans. Hub   240.0          0.010154
# 278        None  Trans. Hub  6610.0          0.279670
#
#      sigmoid_normalized_score                    geometry
# 0                    0.527400  POINT (-21.94832 64.15541)
# 1                    0.524404  POINT (-21.94298 64.15699)
# 2                    0.518069  POINT (-21.95138 64.15259)
# 3                    0.509942  POINT (-21.94872 64.15330)
# 4                    0.511623  POINT (-21.81625 64.11891)
# ..                        ...                         ...
# 274                  0.525892  POINT (-21.92085 64.13411)
# 275                  0.505500  POINT (-21.92006 64.13394)
# 276                  0.528212  POINT (-21.92016 64.13419)
# 277                  0.502539  POINT (-21.86726 64.15623)
# 278                  0.569465  POINT (-21.86477 64.15613)
#
# [279 rows x 11 columns]

# %%
def estimate_normalized_score_for_lattice(poi_data, points, radius):
    """
    Efficiently estimate the total normalized score for a lattice of points.

    Parameters:
    - poi_data (GeoDataFrame): GeoDataFrame containing POI data with a 'normalized_score' column.
    - points (list of tuples): List of (longitude, latitude) tuples representing locations to search near.
    - radius (float): The search radius in meters.

    Returns:
    - results (list of dict): List containing total normalized score and nearby POIs for each point.
    """
    # Reproject GeoDataFrame to metric CRS only once
    poi_metric = poi_data.to_crs(epsg=3857)
    spatial_index = poi_metric.sindex  # Build spatial index once

    # Reproject all points to metric CRS at once
    points_metric = gpd.GeoSeries(
        [Point(pt) for pt in points], crs=poi_data.crs
    ).to_crs(epsg=3857)

    results = []
    for idx, point in enumerate(points_metric):
        # Create a buffer around the point
        search_area = point.buffer(radius)

        # Use the spatial index to find potential matches
        possible_matches_index = list(
            spatial_index.intersection(search_area.bounds))
        possible_matches = poi_metric.iloc[possible_matches_index]

        # Filter with exact intersection
        nearby_pois = possible_matches[possible_matches.intersects(
            search_area)]

        # Calculate the total normalized score
        total_normalized_score = nearby_pois['normalized_score'].sum()

        category_scores = {}
        for category in poi_data['category'].unique():
            nearby_pois_category = nearby_pois[nearby_pois['category'] == category]
            total_normalized_score_category = nearby_pois_category['normalized_score'].sum(
            )
            category_scores[f'{category}_score'] = total_normalized_score_category

        results.append({
            "point_index": idx,
            "latitude": points[idx][1],
            "longitude": points[idx][0],
            "location": points[idx],
            "total_normalized_score": total_normalized_score,
            **category_scores,
            "nearby_pois": nearby_pois
        })

    return results

# %%
results = estimate_normalized_score_for_lattice(
    poi_data, lattice_points, standard_variables['standard_variables']['cutoff_radius']['value'])

# Convert to DataFrame
normalized_score_results_df = pd.DataFrame(results)

# Save as CSV
normalized_score_results_df.to_csv(
    "../data/lattice_normalized_score.csv", index=False)

print("Normalized score results have been saved as 'lattice_normalized_score.csv'.")
# Out:
# Normalized score results have been saved as 'lattice_normalized_score.csv'.

# %%
results
# Out:
# [{'point_index': 0,
#   'latitude': 64.033992,
#   'longitude': -22.083955,
#   'location': (-22.083955, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 1,
#   'latitude': 64.033992,
#   'longitude': -22.083056684715878,
#   'location': (-22.083056684715878, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 2,
#   'latitude': 64.033992,
#   'longitude': -22.08215836943176,
#   'location': (-22.08215836943176, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 3,
#   'latitude': 64.033992,
#   'longitude': -22.08126005414764,
#   'location': (-22.08126005414764, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 4,
#   'latitude': 64.033992,
#   'longitude': -22.08036173886352,
#   'location': (-22.08036173886352, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 5,
#   'latitude': 64.033992,
#   'longitude': -22.0794634235794,
#   'location': (-22.0794634235794, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 6,
#   'latitude': 64.033992,
#   'longitude': -22.078565108295283,
#   'location': (-22.078565108295283, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 7,
#   'latitude': 64.033992,
#   'longitude': -22.07766679301116,
#   'location': (-22.07766679301116, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 8,
#   'latitude': 64.033992,
#   'longitude': -22.076768477727043,
#   'location': (-22.076768477727043, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 9,
#   'latitude': 64.033992,
#   'longitude': -22.075870162442925,
#   'location': (-22.075870162442925, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 10,
#   'latitude': 64.033992,
#   'longitude': -22.074971847158803,
#   'location': (-22.074971847158803, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 11,
#   'latitude': 64.033992,
#   'longitude': -22.074073531874685,
#   'location': (-22.074073531874685, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 12,
#   'latitude': 64.033992,
#   'longitude': -22.073175216590567,
#   'location': (-22.073175216590567, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 13,
#   'latitude': 64.033992,
#   'longitude': -22.072276901306445,
#   'location': (-22.072276901306445, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 14,
#   'latitude': 64.033992,
#   'longitude': -22.071378586022327,
#   'location': (-22.071378586022327, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 15,
#   'latitude': 64.033992,
#   'longitude': -22.07048027073821,
#   'location': (-22.07048027073821, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 16,
#   'latitude': 64.033992,
#   'longitude': -22.069581955454087,
#   'location': (-22.069581955454087, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 17,
#   'latitude': 64.033992,
#   'longitude': -22.06868364016997,
#   'location': (-22.06868364016997, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 18,
#   'latitude': 64.033992,
#   'longitude': -22.067785324885847,
#   'location': (-22.067785324885847, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 19,
#   'latitude': 64.033992,
#   'longitude': -22.066887009601725,
#   'location': (-22.066887009601725, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 20,
#   'latitude': 64.033992,
#   'longitude': -22.065988694317607,
#   'location': (-22.065988694317607, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 21,
#   'latitude': 64.033992,
#   'longitude': -22.06509037903349,
#   'location': (-22.06509037903349, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 22,
#   'latitude': 64.033992,
#   'longitude': -22.064192063749367,
#   'location': (-22.064192063749367, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 23,
#   'latitude': 64.033992,
#   'longitude': -22.06329374846525,
#   'location': (-22.06329374846525, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 24,
#   'latitude': 64.033992,
#   'longitude': -22.06239543318113,
#   'location': (-22.06239543318113, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 25,
#   'latitude': 64.033992,
#   'longitude': -22.06149711789701,
#   'location': (-22.06149711789701, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 26,
#   'latitude': 64.033992,
#   'longitude': -22.06059880261289,
#   'location': (-22.06059880261289, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 27,
#   'latitude': 64.033992,
#   'longitude': -22.059700487328772,
#   'location': (-22.059700487328772, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 28,
#   'latitude': 64.033992,
#   'longitude': -22.05880217204465,
#   'location': (-22.05880217204465, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 29,
#   'latitude': 64.033992,
#   'longitude': -22.057903856760532,
#   'location': (-22.057903856760532, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 30,
#   'latitude': 64.033992,
#   'longitude': -22.057005541476414,
#   'location': (-22.057005541476414, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 31,
#   'latitude': 64.033992,
#   'longitude': -22.056107226192292,
#   'location': (-22.056107226192292, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 32,
#   'latitude': 64.033992,
#   'longitude': -22.055208910908174,
#   'location': (-22.055208910908174, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 33,
#   'latitude': 64.033992,
#   'longitude': -22.054310595624056,
#   'location': (-22.054310595624056, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 34,
#   'latitude': 64.033992,
#   'longitude': -22.053412280339934,
#   'location': (-22.053412280339934, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 35,
#   'latitude': 64.033992,
#   'longitude': -22.052513965055816,
#   'location': (-22.052513965055816, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 36,
#   'latitude': 64.033992,
#   'longitude': -22.051615649771698,
#   'location': (-22.051615649771698, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 37,
#   'latitude': 64.033992,
#   'longitude': -22.050717334487576,
#   'location': (-22.050717334487576, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 38,
#   'latitude': 64.033992,
#   'longitude': -22.049819019203458,
#   'location': (-22.049819019203458, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 39,
#   'latitude': 64.033992,
#   'longitude': -22.04892070391934,
#   'location': (-22.04892070391934, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 40,
#   'latitude': 64.033992,
#   'longitude': -22.048022388635218,
#   'location': (-22.048022388635218, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 41,
#   'latitude': 64.033992,
#   'longitude': -22.0471240733511,
#   'location': (-22.0471240733511, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 42,
#   'latitude': 64.033992,
#   'longitude': -22.04622575806698,
#   'location': (-22.04622575806698, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 43,
#   'latitude': 64.033992,
#   'longitude': -22.04532744278286,
#   'location': (-22.04532744278286, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 44,
#   'latitude': 64.033992,
#   'longitude': -22.04442912749874,
#   'location': (-22.04442912749874, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 45,
#   'latitude': 64.033992,
#   'longitude': -22.04353081221462,
#   'location': (-22.04353081221462, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 46,
#   'latitude': 64.033992,
#   'longitude': -22.042632496930498,
#   'location': (-22.042632496930498, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 47,
#   'latitude': 64.033992,
#   'longitude': -22.04173418164638,
#   'location': (-22.04173418164638, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 48,
#   'latitude': 64.033992,
#   'longitude': -22.04083586636226,
#   'location': (-22.04083586636226, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 49,
#   'latitude': 64.033992,
#   'longitude': -22.03993755107814,
#   'location': (-22.03993755107814, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 50,
#   'latitude': 64.033992,
#   'longitude': -22.03903923579402,
#   'location': (-22.03903923579402, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 51,
#   'latitude': 64.033992,
#   'longitude': -22.038140920509903,
#   'location': (-22.038140920509903, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 52,
#   'latitude': 64.033992,
#   'longitude': -22.03724260522578,
#   'location': (-22.03724260522578, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 53,
#   'latitude': 64.033992,
#   'longitude': -22.036344289941663,
#   'location': (-22.036344289941663, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 54,
#   'latitude': 64.033992,
#   'longitude': -22.035445974657545,
#   'location': (-22.035445974657545, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 55,
#   'latitude': 64.033992,
#   'longitude': -22.034547659373423,
#   'location': (-22.034547659373423, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 56,
#   'latitude': 64.033992,
#   'longitude': -22.033649344089305,
#   'location': (-22.033649344089305, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 57,
#   'latitude': 64.033992,
#   'longitude': -22.032751028805187,
#   'location': (-22.032751028805187, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 58,
#   'latitude': 64.033992,
#   'longitude': -22.031852713521065,
#   'location': (-22.031852713521065, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 59,
#   'latitude': 64.033992,
#   'longitude': -22.030954398236947,
#   'location': (-22.030954398236947, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 60,
#   'latitude': 64.033992,
#   'longitude': -22.03005608295283,
#   'location': (-22.03005608295283, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 61,
#   'latitude': 64.033992,
#   'longitude': -22.029157767668707,
#   'location': (-22.029157767668707, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 62,
#   'latitude': 64.033992,
#   'longitude': -22.02825945238459,
#   'location': (-22.02825945238459, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 63,
#   'latitude': 64.033992,
#   'longitude': -22.02736113710047,
#   'location': (-22.02736113710047, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 64,
#   'latitude': 64.033992,
#   'longitude': -22.02646282181635,
#   'location': (-22.02646282181635, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 65,
#   'latitude': 64.033992,
#   'longitude': -22.02556450653223,
#   'location': (-22.02556450653223, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 66,
#   'latitude': 64.033992,
#   'longitude': -22.024666191248112,
#   'location': (-22.024666191248112, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 67,
#   'latitude': 64.033992,
#   'longitude': -22.02376787596399,
#   'location': (-22.02376787596399, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 68,
#   'latitude': 64.033992,
#   'longitude': -22.022869560679872,
#   'location': (-22.022869560679872, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 69,
#   'latitude': 64.033992,
#   'longitude': -22.021971245395754,
#   'location': (-22.021971245395754, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 70,
#   'latitude': 64.033992,
#   'longitude': -22.021072930111632,
#   'location': (-22.021072930111632, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 71,
#   'latitude': 64.033992,
#   'longitude': -22.020174614827514,
#   'location': (-22.020174614827514, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 72,
#   'latitude': 64.033992,
#   'longitude': -22.019276299543392,
#   'location': (-22.019276299543392, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 73,
#   'latitude': 64.033992,
#   'longitude': -22.018377984259274,
#   'location': (-22.018377984259274, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 74,
#   'latitude': 64.033992,
#   'longitude': -22.017479668975152,
#   'location': (-22.017479668975152, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 75,
#   'latitude': 64.033992,
#   'longitude': -22.016581353691034,
#   'location': (-22.016581353691034, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 76,
#   'latitude': 64.033992,
#   'longitude': -22.015683038406912,
#   'location': (-22.015683038406912, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 77,
#   'latitude': 64.033992,
#   'longitude': -22.014784723122794,
#   'location': (-22.014784723122794, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 78,
#   'latitude': 64.033992,
#   'longitude': -22.013886407838676,
#   'location': (-22.013886407838676, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 79,
#   'latitude': 64.033992,
#   'longitude': -22.012988092554554,
#   'location': (-22.012988092554554, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 80,
#   'latitude': 64.033992,
#   'longitude': -22.012089777270436,
#   'location': (-22.012089777270436, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 81,
#   'latitude': 64.033992,
#   'longitude': -22.011191461986318,
#   'location': (-22.011191461986318, 64.033992),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
# ...
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 974,
#   'latitude': 64.03438531365161,
#   'longitude': -21.65276366362263,
#   'location': (-21.65276366362263, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 975,
#   'latitude': 64.03438531365161,
#   'longitude': -21.65186534833851,
#   'location': (-21.65186534833851, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 976,
#   'latitude': 64.03438531365161,
#   'longitude': -21.65096703305439,
#   'location': (-21.65096703305439, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 977,
#   'latitude': 64.03438531365161,
#   'longitude': -21.65006871777027,
#   'location': (-21.65006871777027, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 978,
#   'latitude': 64.03438531365161,
#   'longitude': -21.64917040248615,
#   'location': (-21.64917040248615, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 979,
#   'latitude': 64.03438531365161,
#   'longitude': -21.64827208720203,
#   'location': (-21.64827208720203, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 980,
#   'latitude': 64.03438531365161,
#   'longitude': -21.64737377191791,
#   'location': (-21.64737377191791, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 981,
#   'latitude': 64.03438531365161,
#   'longitude': -21.64647545663379,
#   'location': (-21.64647545663379, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 982,
#   'latitude': 64.03438531365161,
#   'longitude': -21.645577141349673,
#   'location': (-21.645577141349673, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 983,
#   'latitude': 64.03438531365161,
#   'longitude': -21.64467882606555,
#   'location': (-21.64467882606555, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 984,
#   'latitude': 64.03438531365161,
#   'longitude': -21.643780510781433,
#   'location': (-21.643780510781433, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 985,
#   'latitude': 64.03438531365161,
#   'longitude': -21.642882195497315,
#   'location': (-21.642882195497315, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 986,
#   'latitude': 64.03438531365161,
#   'longitude': -21.641983880213193,
#   'location': (-21.641983880213193, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 987,
#   'latitude': 64.03438531365161,
#   'longitude': -21.641085564929075,
#   'location': (-21.641085564929075, 64.03438531365161),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 988,
#   'latitude': 64.03477862175916,
#   'longitude': -22.083955,
#   'location': (-22.083955, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 989,
#   'latitude': 64.03477862175916,
#   'longitude': -22.083056684715878,
#   'location': (-22.083056684715878, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 990,
#   'latitude': 64.03477862175916,
#   'longitude': -22.08215836943176,
#   'location': (-22.08215836943176, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 991,
#   'latitude': 64.03477862175916,
#   'longitude': -22.08126005414764,
#   'location': (-22.08126005414764, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 992,
#   'latitude': 64.03477862175916,
#   'longitude': -22.08036173886352,
#   'location': (-22.08036173886352, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 993,
#   'latitude': 64.03477862175916,
#   'longitude': -22.0794634235794,
#   'location': (-22.0794634235794, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 994,
#   'latitude': 64.03477862175916,
#   'longitude': -22.078565108295283,
#   'location': (-22.078565108295283, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 995,
#   'latitude': 64.03477862175916,
#   'longitude': -22.07766679301116,
#   'location': (-22.07766679301116, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 996,
#   'latitude': 64.03477862175916,
#   'longitude': -22.076768477727043,
#   'location': (-22.076768477727043, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 997,
#   'latitude': 64.03477862175916,
#   'longitude': -22.075870162442925,
#   'location': (-22.075870162442925, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 998,
#   'latitude': 64.03477862175916,
#   'longitude': -22.074971847158803,
#   'location': (-22.074971847158803, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  {'point_index': 999,
#   'latitude': 64.03477862175916,
#   'longitude': -22.074073531874685,
#   'location': (-22.074073531874685, 64.03477862175916),
#   'total_normalized_score': 0.0,
#   'Tourism_score': 0.0,
#   'GymsSports_score': 0.0,
#   'Commercial Dist._score': 0.0,
#   'ParksStreetRecreationReligious._score': 0.0,
#   'Pools_score': 0.0,
#   'Adm. Districts_score': 0.0,
#   'EduLibHealthcare_score': 0.0,
#   'Trans. Hub_score': 0.0,
#   'nearby_pois': Empty GeoDataFrame
#   Columns: [Name, Latitude, Longitude, Weight, Reviews, Type, category, score, normalized_score, sigmoid_normalized_score, geometry]
#   Index: []},
#  ...]

# %%
final_score_df = population_results_df[[
    'point_index', 'latitude', 'longitude']].copy()
final_score_df['parking'] = results_df['total_capacity']
final_score_df['population_2025'] = population_results_df['total_population_2025']
final_score_df['population_2029'] = population_results_df['total_population_2029']
final_score_df['population_2030'] = population_results_df['total_population_2030']

final_score_df['final_score'] = 0.1*0.001*results_df['total_capacity']+0.001*population_results_df['total_population_2025']+0.001 * \
    population_results_df['total_population_2029']+0.001*population_results_df['total_population_2030'] + \
    100*normalized_score_results_df['total_normalized_score']
display(final_score_df)

final_score_df.to_csv("../data/lattice_final_score.csv", index=False)
# Out:
#         point_index   latitude  longitude  parking  population_2025  \
# 0                 0  64.033992 -22.083955      0.0         0.000000
# 1                 1  64.033992 -22.083057      0.0         0.000000
# 2                 2  64.033992 -22.082158      0.0         0.000000
# 3                 3  64.033992 -22.081260      0.0         0.000000
# 4                 4  64.033992 -22.080362      0.0         0.000000
# ...             ...        ...        ...      ...              ...
# 195619       195619  64.188920 -21.644679      0.0         0.000000
# 195620       195620  64.188920 -21.643781      0.0         0.455864
# 195621       195621  64.188920 -21.642882      0.0         0.455864
# 195622       195622  64.188920 -21.641984      0.0         0.455864
# 195623       195623  64.188920 -21.641086      0.0         0.455864
#
#         population_2029  population_2030  final_score
# 0              0.000000         0.000000     0.000000
# 1              0.000000         0.000000     0.000000
# 2              0.000000         0.000000     0.000000
# 3              0.000000         0.000000     0.000000
# 4              0.000000         0.000000     0.000000
# ...                 ...              ...          ...
# 195619         0.000000         0.000000     0.000000
# 195620         0.455864         0.455864     0.001368
# 195621         0.455864         0.455864     0.001368
# 195622         0.455864         0.455864     0.001368
# 195623         0.455864         0.455864     0.001368
#
# [195624 rows x 8 columns]
